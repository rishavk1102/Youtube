# %%
import pandas as pd

# %%
df = pd.read_csv('ramen-ratings.csv')

# %%
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country  Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan   3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan   1.00
# 2                      Cup Noodles Chicken Vegetable   Cup     USA   2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan   2.75
# 4                                    Singapore Curry  Pack   India   3.75
#
#    Top Ten
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df.tail()
# Out:
#      Review #    Brand                                            Variety  \
# 110      2470    Myojo  Udon Japanese Style Noodles With Soup Base Hot...
# 111      2469     KOKA             Signature Curry Flavor Instant Noodles
# 112      2468  Acecook                              Dossari Yasai Chanpon
# 113      2467    Paldo                           Volcano Curry Kkokkomyun
# 114      2466  Sau Tao       Instant Noodle King Pepper Duck Flavour Soup
#
#     Style      Country  Stars  Top Ten
# 110  Pack          USA   3.75      NaN
# 111   Cup    Singapore   3.50      NaN
# 112   Cup        Japan   4.25      NaN
# 113  Pack  South Korea   3.50      NaN
# 114  Pack    Hong Kong   4.00      NaN

# %%
df['Brand']
# Out:
# 0           New Touch
# 1            Just Way
# 2              Nissin
# 3             Wei Lih
# 4      Ching's Secret
#             ...
# 110             Myojo
# 111              KOKA
# 112           Acecook
# 113             Paldo
# 114           Sau Tao
# Name: Brand, Length: 115, dtype: object

# %%
df['Stars']
# Out:
# 0      3.75
# 1      1.00
# 2      2.25
# 3      2.75
# 4      3.75
#        ...
# 110    3.75
# 111    3.50
# 112    4.25
# 113    3.50
# 114    4.00
# Name: Stars, Length: 115, dtype: float64

# %%
df['Stars'].max()
# Out:
# 5.0

# %%
df['Stars'].min()
# Out:
# 0.0

# %%
df['Brand'][df['Stars'] == 5.0]
# Out:
# 10                Tao Kae Noi
# 11                   Yamachan
# 14                     Nissin
# 17                   Yamachan
# 21           Jackpot Teriyaki
# 22                       KOKA
# 28                    MyKuali
# 30              Samyang Foods
# 35                       KOKA
# 37                       KOKA
# 39                     Nissin
# 42                     Nissin
# 43                     Nissin
# 45                     Nissin
# 47                   Nongshim
# 52                      Prima
# 56                     Nissin
# 58                   Takamori
# 60                     Nissin
# 65              Uni-President
# 68           Mom's Dry Noodle
# 69              Samyang Foods
# 70                    MyKuali
# 80     The Ramen Rater Select
# 81                       KOKA
# 89                     Nissin
# 97                      Paldo
# 102               Kiki Noodle
# 103               Kiki Noodle
# 109                    Nissin
# Name: Brand, dtype: object

# %%
df['Variety'][df['Stars'] == 4.0]
# Out:
# 6               Spice Deli Tantan Men With Cilantro
# 18                                       Mi Hai Cua
# 19                                  Premium Gomtang
# 29         Signature Tom Yum Flavor Instant Noodles
# 33                      Chongqing Spicy Hot Noodles
# 46                    Hokkaido Hakodate Shoyu Ramen
# 62                                      Umami Ramen
# 73                          RMy Noodlez Rumput Laut
# 79                               Toona Paste Noodle
# 96                      Demae Ramen Tokyo Soy Sauce
# 101                 Instant Noodles Chicken Flavour
# 104                              Kimchi Stew Ramyun
# 114    Instant Noodle King Pepper Duck Flavour Soup
# Name: Variety, dtype: object

# %%
df[2:6]
# Out:
#    Review #           Brand                        Variety Style      Country  \
# 2      2578          Nissin  Cup Noodles Chicken Vegetable   Cup          USA
# 3      2577         Wei Lih  GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4      2576  Ching's Secret                Singapore Curry  Pack        India
# 5      2575   Samyang Foods         Kimchi song Song Ramen  Pack  South Korea
#
#    Stars  Top Ten
# 2   2.25      NaN
# 3   2.75      NaN
# 4   3.75      NaN
# 5   4.75      NaN

# %%
df.columns
# Out:
# Index(['Review #', 'Brand', 'Variety', 'Style', 'Country', 'Stars', 'Top Ten'], dtype='object')

# %%
df.shape
# Out:
# (115, 7)

# %%
df[['Variety', 'Style']][df['Stars'] == 4.0]
# Out:
#                                           Variety Style
# 6             Spice Deli Tantan Men With Cilantro   Cup
# 18                                     Mi Hai Cua  Pack
# 19                                Premium Gomtang  Pack
# 29       Signature Tom Yum Flavor Instant Noodles  Pack
# 33                    Chongqing Spicy Hot Noodles  Bowl
# 46                  Hokkaido Hakodate Shoyu Ramen  Pack
# 62                                    Umami Ramen  Pack
# 73                        RMy Noodlez Rumput Laut  Pack
# 79                             Toona Paste Noodle  Pack
# 96                    Demae Ramen Tokyo Soy Sauce  Pack
# 101               Instant Noodles Chicken Flavour  Pack
# 104                            Kimchi Stew Ramyun  Bowl
# 114  Instant Noodle King Pepper Duck Flavour Soup  Pack

# %%
df[df.Stars == df.Stars.max()]
# Out:
#      Review #                   Brand  \
# 10       2570             Tao Kae Noi
# 11       2569                Yamachan
# 14       2566                  Nissin
# 17       2563                Yamachan
# 21       2559        Jackpot Teriyaki
# 22       2558                    KOKA
# 28       2552                 MyKuali
# 30       2550           Samyang Foods
# 35       2545                    KOKA
# 37       2543                    KOKA
# 39       2541                  Nissin
# 42       2538                  Nissin
# 43       2537                  Nissin
# 45       2535                  Nissin
# 47       2533                Nongshim
# 52       2528                   Prima
# 56       2524                  Nissin
# 58       2522                Takamori
# 60       2520                  Nissin
# 65       2515           Uni-President
# 68       2512        Mom's Dry Noodle
# 69       2511           Samyang Foods
# 70       2510                 MyKuali
# ...

# %%
df.Brand[df.Stars == df.Stars.max()]
# Out:
# 10                Tao Kae Noi
# 11                   Yamachan
# 14                     Nissin
# 17                   Yamachan
# 21           Jackpot Teriyaki
# 22                       KOKA
# 28                    MyKuali
# 30              Samyang Foods
# 35                       KOKA
# 37                       KOKA
# 39                     Nissin
# 42                     Nissin
# 43                     Nissin
# 45                     Nissin
# 47                   Nongshim
# 52                      Prima
# 56                     Nissin
# 58                   Takamori
# 60                     Nissin
# 65              Uni-President
# 68           Mom's Dry Noodle
# 69              Samyang Foods
# 70                    MyKuali
# 80     The Ramen Rater Select
# 81                       KOKA
# 89                     Nissin
# 97                      Paldo
# 102               Kiki Noodle
# 103               Kiki Noodle
# 109                    Nissin
# Name: Brand, dtype: object

# %%
g = df.groupby('Style')

g

# %%
for Style, Style_df in g:
    print(Style)
    print(Style_df)
    print()
    print()
# Out:
# Bowl
#      Review #             Brand  \
# 13       2567            Nissin
# 25       2555     Samyang Foods
# 27       2553            Nissin
# 28       2552           MyKuali
# 33       2547  Sichuan Guangyou
# 34       2546         New Touch
# 48       2532            Nissin
# 51       2529          Maruchan
# 54       2526     Samyang Foods
# 63       2517       Ikeda Shoku
# 65       2515     Uni-President
# 69       2511     Samyang Foods
# 75       2505           Acecook
# 77       2503  Sichuan Guangyou
# 97       2483             Paldo
# 100      2480           Acecook
# 104      2476     Samyang Foods
# 105      2475          Maruchan
#
#                                              Variety Style      Country  \
# 13                      Deka Buto Kimchi Pork Flavor  Bowl        Japan
# 25                         Song Song Kimchi Big Bowl  Bowl  South Korea
# 27                Hakata Ramen Noodle White Tonkotsu  Bowl        Japan
# ...

# %%
g.get_group('Cup')
# Out:
#      Review #          Brand  \
# 0        2580      New Touch
# 2        2578         Nissin
# 6        2574        Acecook
# 15       2565           KOKA
# 20       2560         Nissin
# 22       2558           KOKA
# 37       2543           KOKA
# 39       2541         Nissin
# 41       2539         Nissin
# 42       2538         Nissin
# 43       2537         Nissin
# 45       2535         Nissin
# 60       2520         Nissin
# 81       2499           KOKA
# 83       2497         Nissin
# 85       2495         Nissin
# 87       2493         Nissin
# 89       2491         Nissin
# 91       2489         Nissin
# 93       2487         Nissin
# 95       2485         Nissin
# 99       2481  Samyang Foods
# 109      2471         Nissin
# 111      2469           KOKA
# 112      2468        Acecook
#
#                                                Variety Style      Country  \
# 0                            T's Restaurant Tantanmen    Cup        Japan
# ...

# %%
g.max()
# Out:
#        Review #                   Brand  \
# Style
# Bowl       2567           Uni-President
# Box        2544  The Ramen Rater Select
# Can        2513                Pringles
# Cup        2580           Samyang Foods
# Pack       2579                 Yum-Mie
# Tray       2573             Ikeda Shoku
#
#                                               Variety      Country  Stars  \
# Style
# Bowl      Sweet Potato Instant Noodle Sout-Hot Flavor       Taiwan   5.00
# Box                     Supreme Creamy Tom Yum Noodle          USA   5.00
# Can    Nissin Top Ramen Chicken Flavor Potato Crisps           USA   3.50
# Cup                         T's Restaurant Tantanmen           USA   5.00
# Pack                          Yokohama Tonkotsu Shoyu      Vietnam   5.00
# Tray                    Super Cup Yochan Ika Yakisoba  South Korea   3.75
#
#        Top Ten
# Style
# Bowl       NaN
# Box        NaN
# Can        NaN
# Cup        NaN
# Pack       NaN
# Tray       NaN

# %%
g.mean()
# Out:
#           Review #     Stars  Top Ten
# Style
# Bowl   2520.666667  4.222222      NaN
# Box    2522.000000  3.250000      NaN
# Can    2513.000000  3.500000      NaN
# Cup    2519.720000  4.190000      NaN
# Pack   2524.075758  3.837879      NaN
# Tray   2544.666667  2.083333      NaN

# %%
g.describe()
# Out:
#       Review #                                                           \
#          count         mean        std     min     25%     50%      75%
# Style
# Bowl      18.0  2520.666667  29.469825  2475.0  2503.5  2521.5  2546.75
# Box        2.0  2522.000000  31.112698  2500.0  2511.0  2522.0  2533.00
# Can        1.0  2513.000000        NaN  2513.0  2513.0  2513.0  2513.00
# Cup       25.0  2519.720000  36.958896  2468.0  2489.0  2520.0  2543.00
# Pack      66.0  2524.075758  33.921316  2466.0  2496.5  2523.5  2555.50
# Tray       3.0  2544.666667  27.098585  2519.0  2530.5  2542.0  2557.50
#
#               Stars            ...              Top Ten                       \
#           max count      mean  ...    75%   max   count mean std min 25% 50%
# Style                          ...
# Bowl   2567.0  18.0  4.222222  ...  4.750  5.00     0.0  NaN NaN NaN NaN NaN
# Box    2544.0   2.0  3.250000  ...  4.125  5.00     0.0  NaN NaN NaN NaN NaN
# ...

# %% [markdown]
# <h3>Concatenation</h3>

# %%
india_weather = pd.DataFrame({
    'city': ['mumbai', 'delhi', 'bangalore'],
    'temp': [30, 45, 40],
    'humidity': [80, 50, 80]
})

india_weather
# Out:
#         city  temp  humidity
# 0     mumbai    30        80
# 1      delhi    45        50
# 2  bangalore    40        80

# %%
us_weather = pd.DataFrame({
    'city': ['new york', 'california', 'washington'],
    'temp': [21, 14, 35],
    'humidity': [68, 65, 75]
})

us_weather
# Out:
#          city  temp  humidity
# 0    new york    21        68
# 1  california    14        65
# 2  washington    35        75

# %%
df = pd.concat([india_weather, us_weather])

df
# Out:
#          city  temp  humidity
# 0      mumbai    30        80
# 1       delhi    45        50
# 2   bangalore    40        80
# 0    new york    21        68
# 1  california    14        65
# 2  washington    35        75

# %%
df = pd.concat([india_weather, us_weather], ignore_index = True)

df
# Out:
#          city  temp  humidity
# 0      mumbai    30        80
# 1       delhi    45        50
# 2   bangalore    40        80
# 3    new york    21        68
# 4  california    14        65
# 5  washington    35        75

# %%
df = pd.concat([india_weather, us_weather], axis = 1)

df
# Out:
#         city  temp  humidity        city  temp  humidity
# 0     mumbai    30        80    new york    21        68
# 1      delhi    45        50  california    14        65
# 2  bangalore    40        80  washington    35        75

# %% [markdown]
# <h3>Merging</h3>

# %%
temperature_df = pd.DataFrame({
    'city': ['mumbai', 'delhi', 'bangalore', 'jamshedpur'],
    'temperature': [30, 45, 30, 40]
})

temperature_df
# Out:
#          city  temperature
# 0      mumbai           30
# 1       delhi           45
# 2   bangalore           30
# 3  jamshedpur           40

# %%
humidity_df = pd.DataFrame({
    'city':['delhi', 'mumbai', 'bangalore'],
    'humidity': [70, 65, 75]
})

humidity_df
# Out:
#         city  humidity
# 0      delhi        70
# 1     mumbai        65
# 2  bangalore        75

# %%
df = pd.merge(temperature_df, humidity_df, on = 'city')

df
# Out:
#         city  temperature  humidity
# 0     mumbai           30        65
# 1      delhi           45        70
# 2  bangalore           30        75

# %%
df = pd.merge(temperature_df, humidity_df, on = 'city', how = 'outer')

df
# Out:
#          city  temperature  humidity
# 0      mumbai           30      65.0
# 1       delhi           45      70.0
# 2   bangalore           30      75.0
# 3  jamshedpur           40       NaN

# %%
df = pd.DataFrame([1, 2, 3, 4, 5, 6, 7, 8, 9], index = [9, 8, 7, 6, 5, 4, 3, 2, 1]) #assigning custom index
df
# Out:
#    0
# 9  1
# 8  2
# 7  3
# 6  4
# 5  5
# 4  6
# 3  7
# 2  8
# 1  9

# %%
df.loc[4]
# Out:
# 0    6
# Name: 4, dtype: int64

# %%
df.iloc[4]
# Out:
# 0    5
# Name: 5, dtype: int64
