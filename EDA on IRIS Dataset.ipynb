# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('iris.csv')

iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris.shape # how many datapoints are there?
# Out:
# (150, 5)

# %%
iris.columns #What are the features of the data?
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
#How many flowers of each species?
iris['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
# Plotting a 1-D Scatter Plot
iris_setosa = iris.loc[iris['variety'] == 'Setosa']
iris_virginica = iris.loc[iris['variety'] == 'Virginica']
iris_versicolor = iris.loc[iris['variety'] == 'Versicolor']

plt.plot(iris_setosa['petal.length'], np.zeros_like(iris_setosa['petal.length']), 'o')
plt.plot(iris_virginica['petal.length'], np.zeros_like(iris_virginica['petal.length']), 'o')
plt.plot(iris_versicolor['petal.length'], np.zeros_like(iris_versicolor['petal.length']), 'o')

plt.grid()
plt.show()

# %% [markdown]
# # 2D Analysis

# %%
# Plotting 2-D graph
iris.plot(kind='scatter', x='sepal.length', y='sepal.width')
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue='variety', size=4).map(plt.scatter, 'sepal.length', 'sepal.width').add_legend()

plt.show()
# Out:
# /Users/rishav/Documents/Development_Tools/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 3D Analysis
# https://plotly.com/python/3d-scatter-plots/

# %% [markdown]
# # Pair Plots

# %%
sns.set_style('whitegrid')
sns.pairplot(iris, hue='variety', size=3).add_legend()
plt.show()
# Out:
# /Users/rishav/Documents/Development_Tools/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
